# %% [markdown]
# #### <font color="#03997A"> Diplomado en Ciencia de datos UNAM </font>
#
# ##### <font color="#03997A"> Dr: Alejandro Pimentel </font>
#
# ##### <font color="#03997A"> Modulo 6 Aprendizaje de Maquina supervisado </font>
#
# ##### <font color="#03997A"> Tema 2: Regresión Lineal Alumno: Ibarra Ramírez Sergio </font>

# %%
import pandas as pd 
tabla = pd.read_csv("https://gitlab.com/dgtic5/res/-/raw/main/aprendizajeSupervizado/Alumni_Giving_Regression.csv")

tabla
# Out:
#       A     B     C     D     E     F
# 0    24  0.42  0.16  0.59  0.81  0.08
# 1    19  0.49  0.04  0.37  0.69  0.11
# 2    18  0.24  0.17  0.66  0.87  0.31
# 3     8  0.74  0.00  0.81  0.88  0.11
# 4     8  0.95  0.00  0.86  0.92  0.28
# ..   ..   ...   ...   ...   ...   ...
# 118  11  0.54  0.03  0.89  0.94  0.29
# 119  15  0.37  0.22  0.69  0.83  0.13
# 120  23  0.32  0.19  0.59  0.80  0.12
# 121  19  0.43  0.06  0.49  0.73  0.13
# 122  19  0.36  0.11  0.52  0.74  0.10
#
# [123 rows x 6 columns]

# %%
tabla.describe()
# Out:
#                 A           B           C           D           E           F
# count  123.000000  123.000000  123.000000  123.000000  123.000000  123.000000
# mean    17.772358    0.403659    0.136260    0.645203    0.841138    0.141789
# std      4.517385    0.133897    0.060101    0.169794    0.083942    0.080674
# min      6.000000    0.140000    0.000000    0.260000    0.580000    0.020000
# 25%     16.000000    0.320000    0.095000    0.505000    0.780000    0.080000
# 50%     18.000000    0.380000    0.130000    0.640000    0.840000    0.130000
# 75%     20.000000    0.460000    0.180000    0.785000    0.910000    0.170000
# max     31.000000    0.950000    0.310000    0.960000    0.980000    0.410000

# %% [markdown]
# Coeficiente de Correlación
# Número que mide la "fuerza" con la que están correlacionados
#
# 1 = Correlación perfecta
#
# -1 = Correlación perfecta

# %% [markdown]
# Para mostrar las correlaciones entre cada par de variables

# %%
import seaborn as sns

corr_matrix = tabla.corr()  # Calculate correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Uso de pairplot de seaborn para graficar correlacion lineal de pearson entre pares de variables + graficas de frecuencia invidual por varable

# %%
import seaborn as sns

sns.pairplot(tabla)

# %% [markdown]
# Separación de set de datos en train y test

# %% [markdown]
# El profe primer separó la variable dependiente de las independientes

# %%
y = tabla["E"]
X = tabla.drop(["E"],axis=1)

# %% [markdown]
# Para dividir como tal ls datos de trin y test
# #!pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2023)

# %%
X_train.describe()
# Out:
#                A          B          C          D          F
# count  98.000000  98.000000  98.000000  98.000000  98.000000
# mean   17.622449   0.405408   0.133571   0.640204   0.146837
# std     4.537394   0.136821   0.060773   0.176886   0.082769
# min     6.000000   0.140000   0.000000   0.260000   0.020000
# 25%    16.000000   0.322500   0.090000   0.490000   0.090000
# 50%    18.000000   0.380000   0.130000   0.640000   0.130000
# 75%    20.000000   0.457500   0.170000   0.797500   0.190000
# max    31.000000   0.950000   0.310000   0.960000   0.410000

# %%
X_train
# Out:
#       A     B     C     D     F
# 100  11  0.67  0.06  0.74  0.19
# 115  14  0.42  0.10  0.53  0.10
# 50   20  0.38  0.04  0.44  0.10
# 60   21  0.38  0.19  0.70  0.13
# 4     8  0.95  0.00  0.86  0.28
# ..   ..   ...   ...   ...   ...
# 33   19  0.35  0.12  0.82  0.14
# 55   18  0.35  0.16  0.81  0.10
# 70   14  0.37  0.13  0.90  0.22
# 25   18  0.39  0.05  0.38  0.03
# 87    6  0.70  0.13  0.95  0.34
#
# [98 rows x 5 columns]

# %%
y_train
# Out:
# 100    0.89
# 115    0.73
# 50     0.71
# 60     0.89
# 4      0.92
#        ...
# 33     0.94
# 55     0.94
# 70     0.97
# 25     0.72
# 87     0.98
# Name: E, Length: 98, dtype: float64

# %%
X_test.describe()
# Out:
#                A          B          C          D          F
# count  25.000000  25.000000  25.000000  25.000000  25.000000
# mean   18.360000   0.396800   0.146800   0.664800   0.122000
# std     4.480327   0.124154   0.057353   0.139974   0.069881
# min     8.000000   0.190000   0.010000   0.370000   0.020000
# 25%    16.000000   0.320000   0.110000   0.560000   0.080000
# 50%    19.000000   0.380000   0.160000   0.650000   0.120000
# 75%    21.000000   0.460000   0.200000   0.780000   0.150000
# max    28.000000   0.710000   0.240000   0.940000   0.360000

# %%
sns.pairplot(X_train)

# %%
import seaborn as sns

corr_matrix_X_train = X_train.corr()  # Calculate correlation matrix
sns.heatmap(corr_matrix_X_train, annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(X_test)

# %%
import seaborn as sns

corr_matrix_X_test = X_test.corr()  # Calculate correlation matrix
sns.heatmap(corr_matrix_X_test, annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Aplicación del modelo lineal en Python

# %%
from sklearn.linear_model import LinearRegression

# %%
modelo = LinearRegression()

# %% [markdown]
# Se entrena al modelo con model.fit(X_train,y_train)

# %%
modelo.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
modelo_linea_entrenado1 = modelo.fit(X_train,y_train)

# %% [markdown]
# Como saber las pendientes o coficientes que enctró mi modelo

# %%
caracteristicas = X.columns
coef_dict = {}

for coef,caracteristica in zip(modelo.coef_,caracteristicas):
  coef_dict[caracteristica] = coef

print(coef_dict)
# Out:
# {'A': 0.0005507754381414766, 'B': -0.10338784457310382, 'C': -0.09636629144234368, 'D': 0.49898432762593603, 'F': 0.024943021146521804}

# %%
modelo_linea_entrenado1.coef_
# Out:
# array([ 0.00055078, -0.10338784, -0.09636629,  0.49898433,  0.02494302])

# %% [markdown]
# Ahora vamos a predecir usando el modelo de LinearRegression

# %%
y_pred_modelo1 =modelo_linea_entrenado1.predict(X_test)
y_pred_modelo1
# Out:
# array([0.70868586, 0.91776125, 0.86872668, 0.81077792, 0.93922489,
#        0.86144854, 0.76404923, 0.8222382 , 0.79581432, 0.83855492,
#        0.82512859, 0.81846101, 0.80245757, 0.89588953, 0.80403929,
#        0.95862214, 0.81446601, 0.85883628, 0.81335124, 0.91363453,
#        0.96582155, 0.90846995, 0.8042284 , 0.8580995 , 0.93839098])

# %%
from sklearn.metrics import mean_absolute_error

# Assuming you have y_test and y_pred_modelo1 as the true labels and predicted labels, respectively
mae_modelo1 = mean_absolute_error(y_test, y_pred_modelo1)

print("Mean Absolute Error:", mae_modelo1)
# Out:
# Mean Absolute Error: 0.02690976707528465

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y_pred_train = modelo_linea_entrenado1.predict(X_train)
y_pred_train
# Out:
# array([0.86757221, 0.78418527, 0.75249882, 0.86907887, 0.90487626,
#        0.73380735, 0.81929966, 0.84747412, 0.81000007, 0.95388302,
#        0.84689014, 0.81294087, 0.86835854, 0.96124557, 0.7423457 ,
#        0.78718891, 0.92860263, 0.74347182, 0.84012641, 0.85909069,
#        0.95897181, 0.87881463, 0.84304096, 0.87468199, 0.85717879,
#        0.85049817, 0.76414078, 0.77964931, 0.97175295, 0.75787198,
#        0.92091778, 0.82166318, 0.76187936, 0.85892726, 0.84565222,
#        0.94653963, 0.66614715, 0.70587618, 0.72410997, 0.82747678,
#        0.72499108, 0.79351585, 0.95045461, 0.9304714 , 0.94875657,
#        0.91569479, 0.70589591, 0.97672488, 0.84535474, 0.73733283,
#        0.86150961, 0.7970253 , 0.76561524, 0.77054883, 0.829106  ,
#        0.82134517, 0.86670465, 0.7981992 , 0.71161245, 0.95963868,
#        0.94562411, 0.99193889, 0.85286578, 0.82124598, 0.81701366,
#        0.65925152, 0.92878615, 0.91305826, 0.85755063, 0.78257646,
# ...

# %%
x_lin = np.linspace(0.5,1.1,20)
y_lin = x_lin

x_model = y_train
y_model = y_pred_train

fig, ax = plt.subplots()
ax.plot(x_lin,y_lin)
ax.scatter(x_model,y_model,s=60)

# %%
import matplotlib.pyplot as plt

# Assuming you have already fitted a linear regression model called "modelo_linea_entrenado1"
y_pred_modelo1 # Get the predicted values

# Plot predicted values versus true values
plt.scatter(y_test, y_pred_modelo1)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--')  # Add a diagonal line for reference
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('Predicted Values versus True Values')
plt.show()

# Plot residuals
residuals = y_test - y_pred_modelo1# Calculate residuals
plt.scatter(y_pred_modelo1, residuals)
plt.axhline(y=0, color='r', linestyle='--')  # Add a horizontal line at y=0
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals')
plt.show()

# %% [markdown]
# Vamos a intentar usar otro tipo de modelo lineal en Python model2 = sm.OLS(y_train, X_train)

# %%
import statsmodels.api as sm

# Assuming you have already fitted a linear regression model called "modelo_linea_entrenado1"
model2 = sm.OLS(y_train, X_train)  # Specify the model with dependent variable y and independent variable(s) X
results2 = model2.fit()  # Fit the model

# Generate the summary of the model
print(results2.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      E   R-squared (uncentered):                   0.996
# Model:                            OLS   Adj. R-squared (uncentered):              0.995
# Method:                 Least Squares   F-statistic:                              4226.
# Date:                Sat, 03 Jun 2023   Prob (F-statistic):                   5.35e-108
# Time:                        13:31:08   Log-Likelihood:                          143.54
# No. Observations:                  98   AIC:                                     -277.1
# Df Residuals:                      93   BIC:                                     -264.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Ahora vamos a predecir usando el modelo de sm.OLS(y_train, X_train)

# %%
y_pred_modelo2 = results2.predict(X_test)
y_pred_modelo2
# Out:
# 89     0.721982
# 114    0.843724
# 9      0.849958
# 97     0.743612
# 30     1.032879
# 42     0.876497
# 27     0.832820
# 76     0.915693
# 64     0.782762
# 12     0.817210
# 110    0.809363
# 44     0.773883
# 16     0.813776
# 83     0.893084
# 112    0.783552
# 59     0.999704
# 54     0.823455
# 61     0.926198
# 0      0.909293
# 73     0.936545
# 23     0.965155
# 13     1.001224
# 20     0.763888
# 84     0.864336
# 41     0.938548
# dtype: float64

# %%
from sklearn.metrics import mean_absolute_error

# Assuming you have y_test and y_pred_modelo1 as the true labels and predicted labels, respectively
mae_modelo2 = mean_absolute_error(y_test, y_pred_modelo2)

print("Mean Absolute Error:", mae_modelo2)
# Out:
# Mean Absolute Error: 0.04759209953455245

# %%
X_test
# Out:
#       A     B     C     D     F
# 89   22  0.42  0.08  0.37  0.02
# 114  12  0.33  0.21  0.80  0.15
# 9    14  0.49  0.09  0.71  0.14
# 97   19  0.19  0.19  0.55  0.05
# 30   21  0.41  0.16  0.84  0.15
# 42   16  0.49  0.12  0.70  0.12
# 27   28  0.23  0.22  0.46  0.06
# 76   25  0.36  0.20  0.60  0.12
# 64   17  0.44  0.12  0.56  0.06
# 12   19  0.33  0.07  0.61  0.08
# 110  11  0.70  0.01  0.65  0.22
# 44   18  0.30  0.16  0.58  0.12
# 16   22  0.32  0.11  0.54  0.08
# 83   15  0.41  0.20  0.77  0.10
# 112  19  0.32  0.18  0.56  0.08
# 59   15  0.48  0.16  0.90  0.15
# 54   20  0.38  0.14  0.58  0.17
# 61   20  0.47  0.15  0.69  0.16
# 0    24  0.42  0.16  0.59  0.08
# 73   19  0.32  0.20  0.78  0.15
# 23    8  0.71  0.06  0.94  0.36
# 13   21  0.46  0.12  0.78  0.17
# 20   17  0.38  0.11  0.56  0.11
# 84   21  0.22  0.24  0.66  0.02
# 41   16  0.34  0.21  0.84  0.13

# %%
import matplotlib.pyplot as plt

# Assuming you have already fitted a linear regression model called "modelo_linea_entrenado1"
y_pred_modelo2 # Get the predicted values

# Plot predicted values versus true values
plt.scatter(y_test, y_pred_modelo2)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--')  # Add a diagonal line for reference
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('Predicted Values versus True Values')
plt.show()

# Plot residuals
residuals2 = y_test - y_pred_modelo2# Calculate residuals
plt.scatter(y_pred_modelo2, residuals2)
plt.axhline(y=0, color='r', linestyle='--')  # Add a horizontal line at y=0
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residuals')
plt.show()

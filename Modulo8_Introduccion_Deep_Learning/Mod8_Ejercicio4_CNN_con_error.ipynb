# %% [markdown]
# #### <font color="#03997A"> Diplomado en Ciencia de datos UNAM </font>
#
# ##### <font color="#03997A"> Dr: Alejandro Pimentel  </font>
#
# ##### <font color="#03997A"> Modulo 8 Introducción al Deep Learning </font>
#
# ##### <font color="#03997A"> Ejercicio 4 CNN  Alumno: Ibarra Ramírez Sergio </font>

# %% [markdown]
# Se importan los datos de mnist_784 de numeros del 0 al 9 escritos a mano para su "reconocimieto" y clasificacion con una CNN

# %%
import tensorflow as tf
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import normalize
from sklearn.preprocessing import OneHotEncoder

X,y = fetch_openml('mnist_784', as_frame=False, return_X_y=True)

X = normalize(X).reshape(-1,28,28,1)

X_train = X[:60000]
X_test = X[60000:]
y_train = y[:60000]
y_test = y[60000:]

codificador = OneHotEncoder(handle_unknown='ignore',sparse=False)
y_train = codificador.fit_transform(y_train.reshape(-1,1))
y_test = codificador.transform(y_test.reshape(-1,1))

X_train = tf.constant(X_train, dtype=tf.float32)
X_test = tf.constant(X_test, dtype=tf.float32)
y_train = tf.constant(y_train, dtype=tf.float32)
y_test = tf.constant(y_test, dtype=tf.float32)

train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
batch_size = 100 # Hiperparámetro
train_dataset = train_dataset.shuffle(batch_size).batch(batch_size)
# Out:
# c:\Users\Sergio\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\datasets\_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# c:\Users\Sergio\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Se definen los pesos iniciales de la caa de input, si como de las dos capas de tipo CNN. De igual manera se denie que la primera para que tenga 16 filtros y la segunda 32

# %%
b = tf.Variable(tf.random.normal([10]))
W = tf.Variable(tf.random.normal([1568,10]))

filtros1 = tf.Variable(tf.random.normal([4,4,1,16])) # (alto,ancho,canales,num_filtros)
b_conv1 = tf.Variable(tf.random.normal([16]))

filtros2 = tf.Variable(tf.random.normal([4,4,16,32])) # (alto,ancho,canales,num_filtros)
b_conv2 = tf.Variable(tf.random.normal([32]))

optimizador = tf.keras.optimizers.experimental.SGD(learning_rate=0.01)

# %%
# Training loop

epochs = 10

for _ in range(epochs):
  loss_epoch = 0
  for x,y in train_dataset:
    with tf.GradientTape() as gt:

      salida_conv1 = tf.nn.conv2d(x,filtros1,[1,2,2,1],"SAME")
      print(salida_conv1.shape)
      salida_conv1 += b_conv1
      salida_activacion1 = tf.nn.relu(salida_conv1) # Capa no lineal intermedia
      print(salida_activacion1.shape)

      salida_conv2 = tf.nn.conv2d(salida_activacion1,filtros2,[1,2,2,1],"SAME")
      salida_conv2 += b_conv2
      print(salida_conv2.shape)
      salida_activacion2 =tf.nn.relu(salida_conv2) 

      salidaPlana = tf.reshape(salida_conv2,[-1,1568])
      print(salidaPlana.shape)

      operacion_matricial = tf.matmul(salidaPlana,W)+b 
      print(operacion_matricial.shape)

  
      x_ent = tf.nn.softmax_cross_entropy_with_logits(
          logits = operacion_matricial,
          labels = y
      )

      loss = tf.reduce_mean(x_ent)
      optimizador.minimize(loss,[W,b,filtros1,b_conv1, filtros2, b_conv2],gt) # Poderosa

    loss_epoch += loss/len(train_dataset)
  print(loss_epoch)
# Out:
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# tf.Tensor(13.169572, shape=(), dtype=float32)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# ...
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# (100, 14, 14, 16)
# (100, 14, 14, 16)
# (100, 7, 7, 32)
# (100, 1568)
# (100, 10)
# tf.Tensor(2.4408998, shape=(), dtype=float32)

# %% [markdown]
# Se evalua el modelo de CNN entrenado previamente vs los datos de test y se determina el accuracy

# %%
salida_conv1 = tf.nn.conv2d(X_test,filtros1,[1,2,2,1],"SAME")
salida_conv1 += b_conv1
salida_activacion1 = tf.nn.relu(salida_conv1) # Capa no lineal intermedia
salida_conv2 = tf.nn.conv2d(salida_activacion1,filtros2,[1,2,2,1],"SAME")
salida_conv2 += b_conv2
salida_activacion2 =tf.nn.relu(salida_conv2) 

salidaPlana = tf.reshape(salida_conv2,[-1,1568])

operacion_matricial = tf.matmul(salidaPlana,W)+b # Primera capa

probs = tf.nn.softmax(operacion_matricial)

max_preds = tf.argmax(probs,1)
max_trues = tf.argmax(y_test,1)

numCorrectos = tf.equal(max_preds,max_trues)
acc = tf.reduce_mean(tf.cast(numCorrectos,tf.float32)) # Tengo que convertirlo porque el original es booleano
print(acc)
# Out:
# tf.Tensor(0.1012, shape=(), dtype=float32)

# %% [markdown]
# a) En caso de no usar capa no lineal intermedia (despues de la segunda capa de tipo CNN) se tiene un accuracy de ~17 %
# b) En caso de SI usar capa no lineal intermedia (despues de la segunda capa de tipo CNN) se tiene un accuracy de ~11 %

# %% [markdown]
# Intentando otro numero de neuronas y/o arquitectura

# %%
b_2 = tf.Variable(tf.random.normal([10]))
W_2 = tf.Variable(tf.random.normal([784,10]))

filtros1_2 = tf.Variable(tf.random.normal([4,4,1,28])) # (alto,ancho,canales,num_filtros)
b_conv1_2 = tf.Variable(tf.random.normal([28]))

filtros2_2 = tf.Variable(tf.random.normal([4,4,28,56])) # (alto,ancho,canales,num_filtros)
b_conv2_2 = tf.Variable(tf.random.normal([56]))

optimizador_2 = tf.keras.optimizers.experimental.SGD(learning_rate=0.01)

# %%
batch_size = 100

for x, y in train_dataset:
  
  # Conv layers
  print(x.shape) # [100, 28, 28, 1]
  conv1 = tf.nn.conv2d(x, filtros1_2,[1,2,2,1],"SAME") 
  conv1 += b_conv1_2
  print(conv1.shape) # [100, 14, 14, 28]

  salida_activacion1_2 = tf.nn.relu(conv1) # Capa no lineal intermedia

  conv2 = tf.nn.conv2d(conv1, filtros2_2, [1,2,2,1],"SAME")
  conv2 += b_conv2_2
  print(conv2.shape) # [100, 7, 7, 56]

  salida_activacion2_2 = tf.nn.relu(conv2) # Capa no lineal intermedia
  print(salida_activacion2_2.shape) # [100, 7, 7, 56]


  # Flatten
  flat = tf.reshape(salida_activacion2_2, [-1, (1568*2)]) # [100, 784]
  print(flat.shape)

  # Dense 
  logits = tf.matmul(flat, W_2) + b_2
  print(logits.shape) # [100, 10]

  # Loss
  loss = tf.nn.softmax_cross_entropy_with_logits(logits, y)
# Out:
# (100, 28, 28, 1)
# (100, 14, 14, 28)
# (100, 7, 7, 56)
# (100, 7, 7, 56)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# c:\Users\Sergio\Documents\SIR_Personal_Dell\Diplomado_DC_UNAM\Diplomado_DC_UNAM_FULL_Dell\Diplomado_UNAM_DC_Full\Modulo8_Introduccion_Deep_Learning\Mod8_Ejercicio4_CNN.ipynb Cell 13 in <cell line: 3>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Sergio/Documents/SIR_Personal_Dell/Diplomado_DC_UNAM/Diplomado_DC_UNAM_FULL_Dell/Diplomado_UNAM_DC_Full/Modulo8_Introduccion_Deep_Learning/Mod8_Ejercicio4_CNN.ipynb#X20sZmlsZQ%3D%3D?line=17'>18</a> print(salida_activacion2_2.shape) # [100, 7, 7, 56]
#      <a href='vscode-notebook-cell:/c%3A/Users/Sergio/Documents/SIR_Personal_Dell/Diplomado_DC_UNAM/Diplomado_DC_UNAM_FULL_Dell/Diplomado_UNAM_DC_Full/Modulo8_Introduccion_Deep_Learning/Mod8_Ejercicio4_CNN.ipynb#X20sZmlsZQ%3D%3D?line=20'>21</a> # Flatten
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Sergio/Documents/SIR_Personal_Dell/Diplomado_DC_UNAM/Diplomado_DC_UNAM_FULL_Dell/Diplomado_UNAM_DC_Full/Modulo8_Introduccion_Deep_Learning/Mod8_Ejercicio4_CNN.ipynb#X20sZmlsZQ%3D%3D?line=21'>22</a> flat = tf.reshape(salida_activacion2_2, [-1, (1568*2)]) # [100, 784]
#      <a href='vscode-notebook-cell:/c%3A/Users/Sergio/Documents/SIR_Personal_Dell/Diplomado_DC_UNAM/Diplomado_DC_UNAM_FULL_Dell/Diplomado_UNAM_DC_Full/Modulo8_Introduccion_Deep_Learning/Mod8_Ejercicio4_CNN.ipynb#X20sZmlsZQ%3D%3D?line=22'>23</a> print(flat.shape)
#      <a href='vscode-notebook-cell:/c%3A/Users/Sergio/Documents/SIR_Personal_Dell/Diplomado_DC_UNAM/Diplomado_DC_UNAM_FULL_Dell/Diplomado_UNAM_DC_Full/Modulo8_Introduccion_Deep_Learning/Mod8_Ejercicio4_CNN.ipynb#X20sZmlsZQ%3D%3D?line=24'>25</a> # Dense
#
# File c:\Users\Sergio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\Sergio\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: {{function_node __wrapped__Reshape_device_/job:localhost/replica:0/task:0/device:CPU:0}} Input to reshape is a tensor with 274400 values, but the requested shape requires a multiple of 3136 [Op:Reshape]

# %%
salida_conv1 = tf.nn.conv2d(X_test,filtros1,[1,2,2,1],"SAME")
salida_conv1 += b_conv1
salida_activacion1 = tf.nn.relu(salida_conv1) # Capa no lineal intermedia
salida_conv2 = tf.nn.conv2d(salida_activacion1,filtros2,[1,2,2,1],"SAME")
salida_conv2 += b_conv2
salida_activacion2 =tf.nn.relu(salida_conv2) 

salidaPlana = tf.reshape(salida_conv2,[-1,1568])

operacion_matricial = tf.matmul(salidaPlana,W)+b # Primera capa

probs = tf.nn.softmax(operacion_matricial)

max_preds = tf.argmax(probs,1)
max_trues = tf.argmax(y_test,1)

numCorrectos = tf.equal(max_preds,max_trues)
acc = tf.reduce_mean(tf.cast(numCorrectos,tf.float32)) # Tengo que convertirlo porque el original es booleano
print(acc)
